# %%
from stl import mesh
from myplot import plot_mesh
import math

# %%
sponge = mesh.Mesh.from_file('numpy_stl_example_04.stl')

# %%
plot_mesh(sponge)
sponge.rotate([0.0, 0.0, 1.0], math.radians(65))
plot_mesh(sponge)
sponge.rotate([1, 0.0, 0.0], math.radians(40))
plot_mesh(sponge)
